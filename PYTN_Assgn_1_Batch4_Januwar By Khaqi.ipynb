# %% [markdown]
# ### IMPORT LIBRARY PANDAS DAN NUMPY

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### IMPORT LIBRARY MATPLOTLIB

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Membaca File CSV dengan Library Pandas

# %%
df = pd.read_csv("Source/Dataset/london_crime_by_lsoa.csv")
df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# 2                      Other violence      0  2015      5
# 3         Burglary in Other Buildings      0  2016      3
# 4                   Personal Property      0  2008      6
# ...                               ...    ...   ...    ...
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6
#
# [13490604 rows x 7 columns]

# %% [markdown]
# ### Menampilkan 5 Data teratas

# %%
df.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %% [markdown]
# ### Menampilkan 5 Data terakhir

# %%
df.tail()
# Out:
#           lsoa_code     borough               major_category  \
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6

# %% [markdown]
# ### Menampilkan Index dari Dataset CSV

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13490604, step=1)

# %%
df.index.values
# Out:
# array([       0,        1,        2, ..., 13490601, 13490602, 13490603])

# %% [markdown]
# ### Melihat Tipe Data

# %%
df.info
# Out:
# <bound method DataFrame.info of           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# 2                      Other violence      0  2015      5
# 3         Burglary in Other Buildings      0  2016      3
# 4                   Personal Property      0  2008      6
# ...                               ...    ...   ...    ...
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6
#
# [13490604 rows x 7 columns]>

# %% [markdown]
# ### Menampilkan Statistik singkat dari Dataset

# %%
df.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %% [markdown]
# ### Merubah kolom borough menjadi country

# %%
df.rename(columns={'borough':'country'}, inplace=True)
df.head()
# Out:
#    lsoa_code     country               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %% [markdown]
# ### Melakukan Slicing terhadap Kolom yang dipakai

# %%
df_country = df.loc[:,['country','major_category','minor_category','year','value']]
df_country.head()
# Out:
#       country               major_category               minor_category  year  \
# 0     Croydon                     Burglary  Burglary in Other Buildings  2016
# 1   Greenwich  Violence Against the Person               Other violence  2016
# 2     Bromley  Violence Against the Person               Other violence  2015
# 3   Redbridge                     Burglary  Burglary in Other Buildings  2016
# 4  Wandsworth                      Robbery            Personal Property  2008
#
#    value
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# ### melihat data kasus crime per country

# %%
df_summed = df_country.groupby(['country'], as_index=False)['value'].sum()
df_summed
# Out:
#                    country   value
# 0     Barking and Dagenham  149447
# 1                   Barnet  212191
# 2                   Bexley  114136
# 3                    Brent  227551
# 4                  Bromley  184349
# 5                   Camden  275147
# 6           City of London     780
# 7                  Croydon  260294
# 8                   Ealing  251562
# 9                  Enfield  193880
# 10               Greenwich  181568
# 11                 Hackney  217119
# 12  Hammersmith and Fulham  185259
# 13                Haringey  213272
# 14                  Harrow  116848
# 15                Havering  138947
# 16              Hillingdon  209680
# 17                Hounslow  186772
# 18               Islington  230286
# 19  Kensington and Chelsea  171981
# 20    Kingston upon Thames   89306
# 21                 Lambeth  292178
# 22                Lewisham  215137
# 23                  Merton  115654
# 24                  Newham  262024
# 25               Redbridge  183562
# 26    Richmond upon Thames   96771
# 27               Southwark  278809
# 28                  Sutton  100987
# 29           Tower Hamlets  228613
# 30          Waltham Forest  203879
# 31              Wandsworth  204741
# 32             Westminster  455028

# %% [markdown]
# ### Melihat kasus crime per tahun (major_catogory + minor_catogpry)

# %%
df_sum_year = df.groupby(['year'], as_index=False)['value'].sum()
df_sum_year
# Out:
#    year   value
# 0  2008  738641
# 1  2009  717214
# 2  2010  715324
# 3  2011  724915
# 4  2012  737329
# 5  2013  686407
# 6  2014  680183
# 7  2015  711624
# 8  2016  736121

# %% [markdown]
# ### Menampilkan Line Plot

# %%
df_sum_year.set_index('year').plot(kind='line', figsize=(8,6), color='red', linewidth='2')
plt.title('LONDON CRIME 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# <span style="color:purple">Terlihat dari Line Plot di atas  Tahun 2012 - 2014 mengalami penurunan, dan Pada Tahun 2014 - 2016 mengalami kenaikan yang signifikan </span>.

# %% [markdown]
# ### Melihat Jumlah Crime terkecil

# %%
df_sum_year.min()
# Out:
# year       2008
# value    680183
# dtype: int64

# %% [markdown]
# ### Melihat Jumlah Crime terbesar

# %%
df_sum_year.max()
# Out:
# year       2016
# value    738641
# dtype: int64

# %% [markdown]
# ### Menampilkan data dari country

# %%
# melihat area brent
Westminster = df[(df['country']=='Westminster')]
Westminster
# Out:
#           lsoa_code      country               major_category  \
# 21        E01004660  Westminster           Theft and Handling
# 46        E01004678  Westminster              Criminal Damage
# 74        E01032513  Westminster  Violence Against the Person
# 134       E01004674  Westminster           Theft and Handling
# 165       E01004677  Westminster           Theft and Handling
# ...             ...          ...                          ...
# 13490302  E01004711  Westminster  Violence Against the Person
# 13490346  E01004724  Westminster           Theft and Handling
# 13490386  E01004654  Westminster                      Robbery
# 13490545  E01004712  Westminster           Theft and Handling
# 13490565  E01004742  Westminster           Theft and Handling
#
#                                   minor_category  value  year  month
# 21                         Handling Stolen Goods      0  2012      2
# 46                         Other Criminal Damage      0  2008     11
# 74                                  Wounding/GBH      0  2009      9
# 134       Motor Vehicle Interference & Tampering      1  2014      4
# 165                           Other Theft Person      0  2015     10
# ...                                          ...    ...   ...    ...
# 13490302                     Assault with Injury      1  2015      6
# 13490346                        Theft From Shops      1  2008      9
# 13490386                       Personal Property      0  2009     12
# 13490545                             Other Theft     17  2012      6
# 13490565             Theft/Taking of Pedal Cycle      0  2016      9
#
# [366660 rows x 7 columns]

# %%
df_Westminster = Westminster[(Westminster['year'] > 2007)].groupby(['year'])['value'].sum()
df_Westminster
# Out:
# year
# 2008    47846
# 2009    48456
# 2010    48116
# 2011    54243
# 2012    59226
# 2013    53852
# 2014    47564
# 2015    47395
# 2016    48330
# Name: value, dtype: int64

# %% [markdown]
# ### Menampilkan Line Plot Crime Country Barnet dari Tahun 2008 - 2016

# %%
df_Westminster.plot(kind='line', figsize=(30,5), color='red', linewidth='2')
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('LONDON CRIME 2008 - 2016')
plt.show()

# %% [markdown]
# <span style="color:purple">Terlihat dari Line Plot di atas  Tahun 2012 adalah puncak dari jumlah kasus crime di London </span>.

# %% [markdown]
# ### Menampilkan top 5 country dengan jumlah crime tertinggi

# %%
df_summed_sorted = df_summed.sort_values(by='value', ascending=False)
df_summed_sorted.head(5)
# Out:
#         country   value
# 32  Westminster  455028
# 21      Lambeth  292178
# 27    Southwark  278809
# 5        Camden  275147
# 24       Newham  262024

# %%
df_top5 = df_summed_sorted.head(5)
df_top5.set_index('country', inplace = True)
df_top5
# Out:
#               value
# country
# Westminster  455028
# Lambeth      292178
# Southwark    278809
# Camden       275147
# Newham       262024

# %% [markdown]
# ### Menampilkan Area Plot dari top 5 country dengan value crime tertinggi

# %%
mpl.style.use(['ggplot'])
df_top5.plot(kind = 'area',
             stacked = False,
             figsize=(12,4),)
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# <span style="color:purple">Dari Area plot ditunjukan bahwa kota WEstminster merupakan kota dengan jumlah kasus kriminal tertinggi selama tahun 2008 - 2016</span>.

# %% [markdown]
# ### Menampilkan area plot major_category pada country Westminster

# %%
df_Westminster_areaPlot = Westminster[(Westminster['year'] > 2007)].groupby(['major_category','year'])['value'].sum()
df_Westminster_areaPlot.plot(kind='area', figsize=(30,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Major Category Area Westminster 2008-2016')
plt.show()

# %% [markdown]
# <span style="color:darkblue">terlihat bahwa dari data major category untuk kota Westminster kasus yang sering terjadi adalah Theft and Handling</span>.

# %% [markdown]
# ### Menampilkan area plot minor_category pada country Westminster

# %%
df_Westminster_areaPlot = Westminster[(Westminster['year'] > 2007)].groupby(['minor_category','year'])['value'].sum()
df_Westminster_areaPlot.plot(kind='area', figsize=(30,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Minor Category Area Westminster 2008-2016')
plt.show()

# %% [markdown]
# <span style="color:darkblue">terlihat bahwa dari data minor category untuk kota Westminster kasus yang sering terjadi adalah other Theft Person</span>.

# %% [markdown]
# ### Menampilkan Major_Category = Robbery dari Tahun 2008 - 2016

# %%
major = df[(df['year'] > 2007)].groupby(['major_category','year'])['value'].sum()
robbery = major['Robbery']
robbery
df_robbery = robbery.to_frame()
df_robbery = df_robbery.rename(columns={'value': 'Robbery'})
df_robbery
# Out:
#       Robbery
# year
# 2008    29627
# 2009    29568
# 2010    32341
# 2011    36679
# 2012    35260
# 2013    29337
# 2014    22150
# 2015    21383
# 2016    22528

# %% [markdown]
# ### Menampilkan Major_Category = Burglary dari Tahun 2008 - 2016

# %%
burglary = major['Burglary']
burglary
df_burglary = burglary.to_frame()
df_burglary = df_burglary.rename(columns={'value': 'Burglary'})
df_burglary
# Out:
#       Burglary
# year
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %% [markdown]
# ### Menggabungkan 2 data frame

# %%
df_burglary_robbery = pd.concat([df_robbery, df_burglary], axis=1)
df_burglary_robbery
# Out:
#       Robbery  Burglary
# year
# 2008    29627     88092
# 2009    29568     90619
# 2010    32341     86826
# 2011    36679     93315
# 2012    35260     93392
# 2013    29337     87222
# 2014    22150     76053
# 2015    21383     70489
# 2016    22528     68285

# %% [markdown]
# ### Menampilkan Area Plot perbandingan Burlgary dan Robbery dari Tahun 2008 - 2016

# %%
df_burglary_robbery.plot(kind='area', alpha=0.35, figsize=(10,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Burglary and Robbery in London 2008 - 2016')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa hasil compare dari Burglary vs Robbery, selama tahun 2008 - 2016 Burglary masih jadi trend kasus crime di london</span>.

# %% [markdown]
# ### HISTOGRAM Compare Burglary vs Robbery

# %%
df_burglary_robbery.plot(kind='hist')
plt.title("histogram of Burglary and Robbery [2008-2016]")
plt.ylabel('number of years')
plt.xlabel('number of crimes')
plt.show()

# %% [markdown]
# ### Menampilkan Data Frame Country dan Value

# %%
df_bar_sum = df.groupby(['country'], as_index=False)['value'].sum()
df_bar_sum
# Out:
#                    country   value
# 0     Barking and Dagenham  149447
# 1                   Barnet  212191
# 2                   Bexley  114136
# 3                    Brent  227551
# 4                  Bromley  184349
# 5                   Camden  275147
# 6           City of London     780
# 7                  Croydon  260294
# 8                   Ealing  251562
# 9                  Enfield  193880
# 10               Greenwich  181568
# 11                 Hackney  217119
# 12  Hammersmith and Fulham  185259
# 13                Haringey  213272
# 14                  Harrow  116848
# 15                Havering  138947
# 16              Hillingdon  209680
# 17                Hounslow  186772
# 18               Islington  230286
# 19  Kensington and Chelsea  171981
# 20    Kingston upon Thames   89306
# 21                 Lambeth  292178
# 22                Lewisham  215137
# 23                  Merton  115654
# 24                  Newham  262024
# 25               Redbridge  183562
# 26    Richmond upon Thames   96771
# 27               Southwark  278809
# 28                  Sutton  100987
# 29           Tower Hamlets  228613
# 30          Waltham Forest  203879
# 31              Wandsworth  204741
# 32             Westminster  455028

# %% [markdown]
# ### Menampilkan Bar Plot London Crime

# %%
df_bar = df_bar_sum.set_index('country')
df_bar.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Country') # add to x-label to the plot
plt.ylabel('Numbor of Crime') # add y-label to the plot
plt.title('Bar Plot of london_crime') # add title to the plot

plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa kota dengan kasus crime tertinggi adalah Westminster di london</span>.

# %% [markdown]
# ### Menampilkan Bar Plot Compare Burglary vs Robbery

# %%
df_burglary_robbery.plot(kind='bar')
plt.title('Burglary and Robbery [2008-2016]')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa tingkat kejahatan tertinggi untuk Robbery pada tahun 2011, dan Burglary pada tahun 2012</span>.

# %% [markdown]
# ### Menampilkan Bar Plot Compare Burglary vs Robbery

# %%
df_burglary_robbery.plot(kind='barh')
plt.title('Burglary and Robbery [2008-2016]')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa tingkat kejahatan tertinggi untuk Robbery pada tahun 2011, dan Burglary pada tahun 2012</span>.

# %% [markdown]
# ### Menampilkan Bar Plot Crime setiap Tahunnya

# %%
df_sum_year.plot(kind='bar',figsize=(10,7))
plt.title('LONDON CRIME 2008-2016')
plt.ylabel('number of cases')
plt.xlabel('year')

plt.annotate('',xy=(8,760000), xytext=(6,680000), arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='red', lw=2))
plt.annotate('mengalami kenaikan', xy=(6,750000))

plt.show()

# %%
df_pie = df.groupby(['country'], as_index=False)['value'].sum()
df_pie = df_pie.sort_values(by='value', ascending=False)
df_pie = df_pie.head(5)
df_pie_pre = df_pie.set_index('country')

# %% [markdown]
# ### Menampilkan Top 5 Number of Crime tertinggi

# %%
df_pie
# Out:
#         country   value
# 32  Westminster  455028
# 21      Lambeth  292178
# 27    Southwark  278809
# 5        Camden  275147
# 24       Newham  262024

# %% [markdown]
# ### Menampilkan Pie Plot Top 5 Number of Crime Tertinggi

# %%
df_pie_pre['value'].plot(kind='pie',
                            figsize=(5,6),
                            autopct="%1.1f%%",
                            startangle=90,
                            shadow=True);

# %% [markdown]
# <span style="color:darkblue">Di atas merupakan pie chart dari top 5 kota di london dengan kasus tertinggi selama tahun 2008 - 2016</span>.

# %% [markdown]
# ### Menampilkan Box Plot London Crime

# %%
df_box = df.groupby(['year'], as_index=False)['value'].sum()
df_box_pre = df_box.set_index('year')

# %%
df_box_pre.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of london crime')
plt.ylabel('Number of Crime')

plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas tingkat kejahatan tiap tahun di London selama 2008 - 2016</span>.

# %% [markdown]
# ### Menampilkan Box Plot Compare Burglary vs Robbery

# %%
df_burglary_robbery.plot(kind='box', figsize=(8,6))
plt.title('box plot of major category Burglary with Robbery')
plt.ylabel('number of crime')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas adalah hasil perbandingan dari Burglary vs Robbery</span>.

# %% [markdown]
# ### Menampilkan Box Plot Compare Burglary vs Robbery

# %%
df_burglary_robbery.plot(kind='box', figsize=(8,6), vert=False)
plt.title('box plot of major category Burglary with Robbery')
plt.ylabel('number of crime')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas adalah hasil perbandingan dari Burglary vs Robbery</span>.

# %% [markdown]
# ### Menampilkan Number of crime tiap tahunnya

# %%
df_scatter = df.groupby(['year'], as_index=False)['value'].sum()
df_scatter
# Out:
#    year   value
# 0  2008  738641
# 1  2009  717214
# 2  2010  715324
# 3  2011  724915
# 4  2012  737329
# 5  2013  686407
# 6  2014  680183
# 7  2015  711624
# 8  2016  736121

# %% [markdown]
# ### Menampilkan Scatter Plot

# %%
df_scatter.plot(kind='scatter', x='year', y='value', figsize=(10, 6), color='darkblue')
plt.title('London Crime')
plt.xlabel('Year')
plt.ylabel('Value')

plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas adalah persebaran kasus crime di london selama tahun 2008 - 2016</span>.

# %% [markdown]
# ### Import Library Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ### Membuat List dari Nama Country

# %%
stopwords = list(df['country'])
stopwords
# Out:
# ['Croydon',
#  'Greenwich',
#  'Bromley',
#  'Redbridge',
#  'Wandsworth',
#  'Ealing',
#  'Ealing',
#  'Hounslow',
#  'Newham',
#  'Sutton',
#  'Haringey',
#  'Lambeth',
#  'Richmond upon Thames',
#  'Wandsworth',
#  'Hillingdon',
#  'Havering',
#  'Barking and Dagenham',
#  'Redbridge',
#  'Kingston upon Thames',
#  'Sutton',
#  'Redbridge',
#  'Westminster',
#  'Hackney',
#  'Enfield',
#  'Ealing',
#  'Hackney',
#  'Harrow',
#  'Ealing',
#  'Haringey',
#  'Lewisham',
#  'Ealing',
#  'Hounslow',
#  'Bromley',
#  'Havering',
#  'Hillingdon',
#  'Brent',
#  'Haringey',
#  'Hounslow',
#  'Lambeth',
#  'Southwark',
#  'Havering',
#  'Newham',
#  'Croydon',
#  'Croydon',
#  'Barnet',
#  'Waltham Forest',
#  'Westminster',
#  'Lambeth',
#  'Lewisham',
#  'Bromley',
#  'Ealing',
#  'Brent',
#  'Haringey',
#  'Camden',
#  'Bexley',
#  'Croydon',
#  'Lewisham',
#  'Hounslow',
#  'Camden',
#  'Kensington and Chelsea',
#  'Hounslow',
#  'Lewisham',
#  'Kingston upon Thames',
#  'Brent',
#  'Southwark',
#  'Harrow',
#  'Bromley',
#  'Lambeth',
#  'Waltham Forest',
#  'Islington',
#  'Southwark',
#  'Newham',
#  'Barnet',
#  'Brent',
#  'Westminster',
#  'Greenwich',
#  'Redbridge',
#  'Hackney',
#  'Haringey',
#  'Sutton',
#  'Redbridge',
#  'Hackney',
#  'Tower Hamlets',
#  'Croydon',
#  'Hammersmith and Fulham',
#  'Islington',
#  'Newham',
#  'Harrow',
#  'Brent',
#  'Bromley',
#  'Hackney',
#  'Croydon',
#  'Ealing',
#  'Hackney',
#  'Newham',
#  'Haringey',
#  'Havering',
#  'Sutton',
#  'Bexley',
#  'Barnet',
#  'Greenwich',
#  'Sutton',
#  'Lewisham',
#  'Hounslow',
#  'Redbridge',
#  'Hounslow',
#  'Bromley',
#  'Kensington and Chelsea',
#  'Ealing',
#  'Kingston upon Thames',
#  'Hackney',
#  'Richmond upon Thames',
#  'Havering',
#  'Southwark',
#  'Kingston upon Thames',
#  'Newham',
#  'Kensington and Chelsea',
#  'Ealing',
#  'Lewisham',
#  'Barnet',
#  'Croydon',
#  'Barking and Dagenham',
#  'Lambeth',
#  'Southwark',
#  'Hounslow',
#  'Lambeth',
#  'Richmond upon Thames',
#  'Waltham Forest',
#  'Merton',
#  'Hammersmith and Fulham',
#  'Lewisham',
#  'Brent',
#  'Lambeth',
#  'Richmond upon Thames',
#  'Westminster',
#  'Camden',
#  'Barking and Dagenham',
#  'Barking and Dagenham',
#  'Barking and Dagenham',
#  'Croydon',
#  'Hammersmith and Fulham',
#  'Lewisham',
#  'Barnet',
#  'Islington',
#  'Bromley',
#  'Lewisham',
#  'Southwark',
#  'Kingston upon Thames',
#  'Southwark',
#  'Croydon',
#  'Ealing',
#  'Waltham Forest',
#  'Kensington and Chelsea',
#  'Tower Hamlets',
#  'Barking and Dagenham',
#  'Richmond upon Thames',
#  'Kingston upon Thames',
#  'Tower Hamlets',
#  'Merton',
#  'Southwark',
#  'Lambeth',
#  'Waltham Forest',
#  'Camden',
#  'Southwark',
#  'Hounslow',
#  'Westminster',
#  'Kensington and Chelsea',
#  'Redbridge',
#  'Brent',
#  'Lambeth',
#  'Newham',
#  'Barking and Dagenham',
#  'Brent',
#  'Barking and Dagenham',
#  'Haringey',
#  'Croydon',
#  'Hillingdon',
#  'Lewisham',
#  'Barking and Dagenham',
#  'Sutton',
#  'Bexley',
#  'Islington',
#  'Sutton',
#  'Bromley',
#  'Merton',
#  'Hillingdon',
#  'Croydon',
#  'Westminster',
#  'Croydon',
#  'Harrow',
#  'Southwark',
#  'Sutton',
#  'Haringey',
#  'Hounslow',
#  'Lambeth',
#  'Havering',
#  'Bromley',
#  'Enfield',
#  'Hounslow',
#  'Waltham Forest',
#  'Brent',
#  'Hillingdon',
#  'Lambeth',
#  'Redbridge',
#  'Hackney',
#  'Lambeth',
#  'Croydon',
#  'Ealing',
#  'Westminster',
#  'Hounslow',
#  'Hammersmith and Fulham',
#  'Lewisham',
#  'Kensington and Chelsea',
#  'Kingston upon Thames',
#  'Kensington and Chelsea',
#  'Redbridge',
#  'Redbridge',
#  'Hackney',
#  'Westminster',
#  'Tower Hamlets',
#  'Islington',
#  'Greenwich',
#  'Newham',
#  'Croydon',
#  'Redbridge',
#  'Wandsworth',
#  'Bexley',
#  'Westminster',
#  'Redbridge',
#  'Harrow',
#  'Wandsworth',
#  'Redbridge',
#  'Barnet',
#  'Sutton',
#  'Ealing',
#  'Tower Hamlets',
#  'Harrow',
#  'Newham',
#  'Ealing',
#  'Tower Hamlets',
#  'Brent',
#  'Kingston upon Thames',
#  'Bexley',
#  'Merton',
#  'Wandsworth',
#  'Richmond upon Thames',
#  'Newham',
#  'Southwark',
#  'Greenwich',
#  'Kensington and Chelsea',
#  'Brent',
#  'Southwark',
#  'Bromley',
#  'Islington',
#  'Bromley',
#  'Greenwich',
#  'Bromley',
#  'Islington',
#  'Wandsworth',
#  'Westminster',
#  'Hammersmith and Fulham',
#  'Lewisham',
#  'Richmond upon Thames',
#  'Wandsworth',
#  'Croydon',
#  'Bexley',
#  'Hammersmith and Fulham',
#  'Camden',
#  'Hounslow',
#  'Barnet',
#  'Camden',
#  'Haringey',
#  'Hackney',
#  'Ealing',
#  'Islington',
#  'Lambeth',
#  'Merton',
#  'Hammersmith and Fulham',
#  'Wandsworth',
#  'Hounslow',
#  'Westminster',
#  'Enfield',
#  'Havering',
#  'Richmond upon Thames',
#  'Newham',
#  'Redbridge',
#  'Wandsworth',
#  'Bexley',
#  'Kensington and Chelsea',
#  'Ealing',
#  'Barking and Dagenham',
#  'Kensington and Chelsea',
#  'Lewisham',
#  'Ealing',
#  'Croydon',
#  'Barking and Dagenham',
#  'Brent',
#  'Westminster',
#  'Newham',
#  'Hounslow',
#  'Hackney',
#  'Bexley',
#  'Southwark',
#  'Croydon',
#  'Lambeth',
#  'Merton',
#  'Barnet',
#  'Merton',
#  'Barnet',
#  'Ealing',
#  'Croydon',
#  'Hammersmith and Fulham',
#  'Tower Hamlets',
#  'Haringey',
#  'Barking and Dagenham',
#  'Croydon',
#  'Brent',
#  'Harrow',
#  'Islington',
#  'Newham',
#  'Newham',
#  'Kingston upon Thames',
#  'Enfield',
#  'Kensington and Chelsea',
#  'Haringey',
#  'Westminster',
#  'Enfield',
#  'Harrow',
#  'Bromley',
#  'Croydon',
#  'Waltham Forest',
#  'Bromley',
#  'Barnet',
#  'Greenwich',
#  'Redbridge',
#  'Greenwich',
#  'Merton',
#  'Newham',
#  'Redbridge',
#  'Lambeth',
#  'Harrow',
#  'Hackney',
#  'Wandsworth',
#  'Haringey',
#  'Barnet',
#  'Havering',
#  'Kingston upon Thames',
#  'Bromley',
#  'Waltham Forest',
#  'Brent',
#  'Kingston upon Thames',
#  'Enfield',
#  'Barnet',
#  'Brent',
#  'Enfield',
#  'Ealing',
#  'Bromley',
#  'Tower Hamlets',
#  'Lambeth',
#  'Bromley',
#  'Newham',
#  'Bexley',
#  'Barking and Dagenham',
#  'Enfield',
#  'Ealing',
#  'Islington',
#  'Lambeth',
#  'Bromley',
#  'Barnet',
#  'Ealing',
#  'Hammersmith and Fulham',
#  'Barnet',
#  'Wandsworth',
#  'Lewisham',
#  'Camden',
#  'Lambeth',
#  'Barnet',
#  'Wandsworth',
#  'Lewisham',
#  'Waltham Forest',
#  'Hounslow',
#  'Barnet',
#  'Lewisham',
#  'Hammersmith and Fulham',
#  'Waltham Forest',
#  'Waltham Forest',
#  'Sutton',
#  'Croydon',
#  'Merton',
#  'Brent',
#  'Richmond upon Thames',
#  'Westminster',
#  'Havering',
#  'Lambeth',
#  'Haringey',
#  'Barnet',
#  'Southwark',
#  'Wandsworth',
#  'Islington',
#  'Enfield',
#  'Kingston upon Thames',
#  'Hammersmith and Fulham',
#  'Waltham Forest',
#  'Brent',
#  'Ealing',
#  'Havering',
#  'Kensington and Chelsea',
#  'Havering',
#  'Havering',
#  'Lewisham',
#  'Wandsworth',
#  'Hackney',
#  'Islington',
#  'Redbridge',
#  'Enfield',
#  'Havering',
#  'Barking and Dagenham',
#  'Bromley',
#  'Southwark',
#  'Sutton',
#  'Hammersmith and Fulham',
#  'Hackney',
#  'Hackney',
#  'Lewisham',
#  'Hillingdon',
#  'Sutton',
#  'Hackney',
#  'Lambeth',
#  'Bromley',
#  'Westminster',
#  'Westminster',
#  'Havering',
#  'Brent',
#  'Enfield',
#  'Brent',
#  'Haringey',
#  'Bexley',
#  'Islington',
#  'Croydon',
#  'Wandsworth',
#  'Brent',
#  'Kensington and Chelsea',
#  'Merton',
#  'Southwark',
#  'Ealing',
#  'Camden',
#  'Greenwich',
#  'Lambeth',
#  'Lambeth',
#  'Havering',
#  'Hammersmith and Fulham',
#  'Barnet',
#  'Newham',
#  'Croydon',
#  'Hillingdon',
#  'Southwark',
#  'Ealing',
#  'Ealing',
#  'Merton',
#  'Wandsworth',
#  'Sutton',
#  'Islington',
#  'Greenwich',
#  'Newham',
#  'Enfield',
#  'Haringey',
#  'Tower Hamlets',
#  'Islington',
#  'Bromley',
#  'Kingston upon Thames',
#  'Lambeth',
#  'Croydon',
#  'Haringey',
#  'Enfield',
#  'Barking and Dagenham',
#  'Bromley',
#  'Lewisham',
#  'Barking and Dagenham',
#  'Newham',
#  'Tower Hamlets',
#  'Islington',
#  'Wandsworth',
#  'Barnet',
#  'Kensington and Chelsea',
#  'Camden',
#  'Southwark',
#  'Bromley',
#  'Hillingdon',
#  'Wandsworth',
#  'Barking and Dagenham',
#  'Barking and Dagenham',
#  'Wandsworth',
#  'Bexley',
#  'Richmond upon Thames',
#  'Southwark',
#  'Hillingdon',
#  'Havering',
#  'Hammersmith and Fulham',
#  'Hillingdon',
#  'Hounslow',
#  'Hillingdon',
#  'Havering',
#  'Bexley',
#  'Southwark',
#  'Newham',
#  'Southwark',
#  'Tower Hamlets',
#  'Greenwich',
#  'Wandsworth',
#  'Newham',
#  'Tower Hamlets',
#  'Barnet',
#  'Islington',
#  'Enfield',
#  'Barking and Dagenham',
#  'Harrow',
#  'Hammersmith and Fulham',
#  'Waltham Forest',
#  'Haringey',
#  'Wandsworth',
#  'Bromley',
#  'Bromley',
#  'Barking and Dagenham',
#  'Newham',
#  'Southwark',
#  'Lambeth',
#  'Newham',
#  'Newham',
#  'Hillingdon',
#  'Camden',
#  'Hounslow',
#  'Camden',
#  'Hillingdon',
#  'Enfield',
#  'Hillingdon',
#  'Lambeth',
#  'Croydon',
#  'Haringey',
#  'Redbridge',
#  'Enfield',
#  'Barnet',
#  'Bromley',
#  'Hillingdon',
#  'Merton',
#  'Southwark',
#  'Islington',
#  'Hounslow',
#  'Bromley',
#  'Harrow',
#  'Hackney',
#  'Bromley',
#  'Lewisham',
#  'Ealing',
#  'Brent',
#  'Hounslow',
#  'Hounslow',
#  'Haringey',
#  'Newham',
#  'Havering',
#  'Westminster',
#  'Newham',
#  'Newham',
#  'Hounslow',
#  'Havering',
#  'Barking and Dagenham',
#  'Newham',
#  'Richmond upon Thames',
#  'Lambeth',
#  'Bexley',
#  'Hammersmith and Fulham',
#  'Hammersmith and Fulham',
#  'Barnet',
#  'Ealing',
#  'Croydon',
#  'Lambeth',
#  'Haringey',
#  'Redbridge',
#  'Enfield',
#  'Hackney',
#  'Enfield',
#  'Harrow',
#  'Greenwich',
#  'Wandsworth',
#  'Islington',
#  'Richmond upon Thames',
#  'Tower Hamlets',
#  'Haringey',
#  'Brent',
#  'Wandsworth',
#  'Southwark',
#  'Lambeth',
#  'Hackney',
#  'Redbridge',
#  'Bromley',
#  'Havering',
#  'Croydon',
#  'Haringey',
#  'Camden',
#  'Lambeth',
#  'Barnet',
#  'Lambeth',
#  'Merton',
#  'Sutton',
#  'Redbridge',
#  'Kensington and Chelsea',
#  'Hounslow',
#  'Greenwich',
#  'Islington',
#  'Waltham Forest',
#  'Southwark',
#  'Richmond upon Thames',
#  'Sutton',
#  'Brent',
#  'Waltham Forest',
#  'Islington',
#  'Croydon',
#  'Waltham Forest',
#  'Barnet',
#  'Bromley',
#  'Wandsworth',
#  'Ealing',
#  'Newham',
#  'Barnet',
#  'Greenwich',
#  'Hillingdon',
#  'Croydon',
#  'Camden',
#  'Hillingdon',
#  'Hillingdon',
#  'Hillingdon',
#  'Wandsworth',
#  'Waltham Forest',
#  'Southwark',
#  'Barking and Dagenham',
#  'Havering',
#  'Harrow',
#  'Camden',
#  'Bexley',
#  'Hounslow',
#  'Wandsworth',
#  'Harrow',
#  'Merton',
#  'Kingston upon Thames',
#  'Greenwich',
#  'Barking and Dagenham',
#  'Barking and Dagenham',
#  'Barnet',
#  'Hillingdon',
#  'Wandsworth',
#  'Hammersmith and Fulham',
#  'Merton',
#  'Islington',
#  'Hillingdon',
#  'Hillingdon',
#  'Southwark',
#  'Richmond upon Thames',
#  'Bromley',
#  'Enfield',
#  'Islington',
#  'Lambeth',
#  'Merton',
#  'Lambeth',
#  'Newham',
#  'Brent',
#  'Bexley',
#  'Ealing',
#  'Richmond upon Thames',
#  'Ealing',
#  'Ealing',
#  'Islington',
#  'Camden',
#  'Richmond upon Thames',
#  'Richmond upon Thames',
#  'Bromley',
#  'Redbridge',
#  'Redbridge',
#  'Croydon',
#  'Wandsworth',
#  'Lewisham',
#  'Newham',
#  'Bexley',
#  'Ealing',
#  'Lambeth',
#  'Haringey',
#  'Hounslow',
#  'Merton',
#  'Brent',
#  'Barnet',
#  'Ealing',
#  'Redbridge',
#  'Ealing',
#  'Lewisham',
#  'Hammersmith and Fulham',
#  'Croydon',
#  'Lewisham',
#  'Greenwich',
#  'Lambeth',
#  'Westminster',
#  'Sutton',
#  'Croydon',
#  'Westminster',
#  'Hillingdon',
#  'Westminster',
#  'Barking and Dagenham',
#  'Kingston upon Thames',
#  'Enfield',
#  'Haringey',
#  'Croydon',
#  'Croydon',
#  'Brent',
#  'Hammersmith and Fulham',
#  'Westminster',
#  'Croydon',
#  'Bromley',
#  'Waltham Forest',
#  'Haringey',
#  'Hammersmith and Fulham',
#  'Merton',
#  'Bromley',
#  'Greenwich',
#  'Lewisham',
#  'Lambeth',
#  'Westminster',
#  'Bromley',
#  'Redbridge',
#  'Camden',
#  'Sutton',
#  'Merton',
#  'Greenwich',
#  'Havering',
#  'Newham',
#  'Lambeth',
#  'Lewisham',
#  'Kingston upon Thames',
#  'Hillingdon',
#  'Barnet',
#  'Waltham Forest',
#  'Harrow',
#  'Bromley',
#  'Lewisham',
#  'Bexley',
#  'Hammersmith and Fulham',
#  'Bexley',
#  'Hounslow',
#  'Brent',
#  'Croydon',
#  'Redbridge',
#  'Lambeth',
#  'Brent',
#  'Wandsworth',
#  'Havering',
#  'Westminster',
#  'Richmond upon Thames',
#  'Redbridge',
#  'Kingston upon Thames',
#  'Wandsworth',
#  'Kingston upon Thames',
#  'Newham',
#  'Tower Hamlets',
#  'Enfield',
#  'Westminster',
#  'Islington',
#  'Brent',
#  'Westminster',
#  'Havering',
#  'Southwark',
#  'Lambeth',
#  'Southwark',
#  'Kensington and Chelsea',
#  'Westminster',
#  'Kensington and Chelsea',
#  'Hounslow',
#  'Haringey',
#  'Haringey',
#  'Barnet',
#  'Richmond upon Thames',
#  'Havering',
#  'Westminster',
#  'Westminster',
#  'Barking and Dagenham',
#  'Ealing',
#  'Ealing',
#  'Southwark',
#  'Islington',
#  'Waltham Forest',
#  'Westminster',
#  'Redbridge',
#  'Westminster',
#  'Ealing',
#  'Wandsworth',
#  'Kensington and Chelsea',
#  'Croydon',
#  'Kensington and Chelsea',
#  'Wandsworth',
#  'Lambeth',
#  'Merton',
#  'Enfield',
#  'Ealing',
#  'Westminster',
#  'Hillingdon',
#  'Hackney',
#  'Hackney',
#  'Newham',
#  'Camden',
#  'Lewisham',
#  'Camden',
#  'Southwark',
#  'Hammersmith and Fulham',
#  'Newham',
#  'Camden',
#  'Richmond upon Thames',
#  'Newham',
#  'Greenwich',
#  'Kensington and Chelsea',
#  'Brent',
#  'Barking and Dagenham',
#  'Haringey',
#  'Hillingdon',
#  'Brent',
#  'Newham',
#  'Lambeth',
#  'Richmond upon Thames',
#  'Barnet',
#  'Lambeth',
#  'Greenwich',
#  'Croydon',
#  'Hackney',
#  'Southwark',
#  'Croydon',
#  'Tower Hamlets',
#  'Lewisham',
#  'Enfield',
#  'Haringey',
#  'Barnet',
#  'Lewisham',
#  'Islington',
#  'Havering',
#  'Hillingdon',
#  'Lambeth',
#  'Camden',
#  'Waltham Forest',
#  'Islington',
#  'Haringey',
#  'Hackney',
#  'Wandsworth',
#  'Islington',
#  'Merton',
#  'Lambeth',
#  'Lambeth',
#  'Redbridge',
#  'Hackney',
#  'Lambeth',
#  'Croydon',
#  'Southwark',
#  'Westminster',
#  'Enfield',
#  'Havering',
#  'Greenwich',
#  'Greenwich',
#  'Richmond upon Thames',
#  'Hounslow',
#  'Redbridge',
#  'Haringey',
#  'Bexley',
#  'Redbridge',
#  'Greenwich',
#  'Bexley',
#  'Bromley',
#  'Richmond upon Thames',
#  'Richmond upon Thames',
#  'Redbridge',
#  'Haringey',
#  'Bexley',
#  'Southwark',
#  'Newham',
#  'Haringey',
#  'Westminster',
#  'Ealing',
#  'Ealing',
#  'Lewisham',
#  'Harrow',
#  'Richmond upon Thames',
#  'Wandsworth',
#  'Havering',
#  'Greenwich',
#  'Havering',
#  'Wandsworth',
#  'Enfield',
#  'Islington',
#  'Bexley',
#  'Hackney',
#  'Waltham Forest',
#  'Tower Hamlets',
#  'Croydon',
#  'Hammersmith and Fulham',
#  'Southwark',
#  'Waltham Forest',
#  'Bromley',
#  'Hounslow',
#  'Tower Hamlets',
#  'Bexley',
#  'Barnet',
#  'Croydon',
#  'Westminster',
#  'Brent',
#  'Greenwich',
#  'Haringey',
#  'Bexley',
#  'Lewisham',
#  'Bromley',
#  'Enfield',
#  'Ealing',
#  'Haringey',
#  'Enfield',
#  'Barking and Dagenham',
#  'Bexley',
#  'Redbridge',
#  'Richmond upon Thames',
#  'Tower Hamlets',
#  'Newham',
#  'Croydon',
#  'Newham',
#  'Harrow',
#  'Islington',
#  'Southwark',
#  'Hammersmith and Fulham',
#  'Barking and Dagenham',
#  'Wandsworth',
#  'Hillingdon',
#  'Sutton',
#  'Camden',
#  'Tower Hamlets',
#  'Haringey',
#  'Lewisham',
#  'Newham',
#  'Hillingdon',
#  'Hillingdon',
#  'Wandsworth',
#  'Islington',
#  'Ealing',
#  'Bromley',
#  'Greenwich',
#  'Havering',
#  'Merton',
#  'Hammersmith and Fulham',
#  'Lewisham',
#  'Merton',
#  'Wandsworth',
#  'Barnet',
#  'Bromley',
#  'Kingston upon Thames',
#  'Redbridge',
#  'Hounslow',
#  'Greenwich',
#  'Islington',
#  'Bexley',
#  'Waltham Forest',
#  'Sutton',
#  'Barnet',
#  'Bexley',
#  'Hammersmith and Fulham',
#  'Lambeth',
#  'Barnet',
#  'Southwark',
#  'Islington',
#  'Barnet',
#  'Southwark',
#  'Waltham Forest',
#  'Sutton',
#  'Hackney',
#  'Waltham Forest',
#  'Croydon',
#  'Westminster',
#  'Barnet',
#  'Hackney',
#  'Greenwich',
#  'Hillingdon',
#  'Hillingdon',
#  'Merton',
#  'Newham',
#  'Bromley',
#  'Barnet',
#  'Barking and Dagenham',
#  'Greenwich',
#  'Hillingdon',
#  'Lewisham',
#  'Greenwich',
#  'Hillingdon',
#  'Redbridge',
#  'Newham',
#  'Merton',
#  'Harrow',
#  'Kingston upon Thames',
#  'Barnet',
#  'Camden',
#  'Croydon',
#  'Harrow',
#  'Redbridge',
#  'Kingston upon Thames',
#  'Barnet',
#  ...]

# %%
text = ' '.join(df['country'].astype(str).tolist())

# %% [markdown]
# ### Menampilkan Word Cloud

# %%
wordcloud = WordCloud(width=800, height=800, background_color='white', 
               min_font_size=10).generate(text)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas adalah Nama dari country di london dengan kasus crime selama 2008 - 2016</span>.

# %% [markdown]
# ### Import Library Image

# %%
from PIL import Image

# %% [markdown]
# ### Import file image yang akan dijadikan Figure

# %%
mask_wordcloud = np.array(Image.open('Source/Img/kura.jpg'))

# %%
masking = plt.figure()
masking.set_figwidth(5)
masking.set_figheight(5)
plt.imshow(mask_wordcloud, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
plt.imshow(mask_wordcloud,cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Menampilkan Wordcloud pada Figur

# %%
wordcloud = WordCloud(width=800, height=800, background_color='white', 
               mask=mask_wordcloud, stopwords=stopwords)
wordcloud.generate(text)
masking=plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Import Library Seaborn, Folium

# %%
# !pip install seaborn
import seaborn as sns
# !pip install folium
import folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/yayan/.local/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/yayan/.local/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/yayan/.local/lib/python3.10/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=0.25 in /home/yayan/.local/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yayan/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yayan/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yayan/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/yayan/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yayan/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in /home/yayan/.local/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /home/yayan/.local/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: numpy in /home/yayan/.local/lib/python3.10/site-packages (from folium) (1.24.2)
# Requirement already satisfied: branca>=0.6.0 in /home/yayan/.local/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /home/yayan/.local/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from folium) (2.25.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2>=2.9->folium) (2.0.1)

# %% [markdown]
# ### Deklarasi Longitude dan Latitude dari Region London

# %%
latitude= 51.509865
longitude= -0.118092

# %% [markdown]
# ### Menampilkan Foliom Map dari London

# %%
region = folium.Map(location=[latitude,longitude],zoom_start=12)
region
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d47f44c34f8ec0e4bcc4e780cb8736b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d47f44c34f8ec0e4bcc4e780cb8736b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d47f44c34f8ec0e4bcc4e780cb8736b3 = L.map(
#                 &quot;map_d47f44c34f8ec0e4bcc4e780cb8736b3&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82a18a9a6c9cc5f4f578424dc29d4c8a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d47f44c34f8ec0e4bcc4e780cb8736b3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Merubah Tampilan Folium map

# %%
# Mengganti Tipe Peta
region_london = folium.Map(location=[latitude,longitude],zoom_start=11,tiles='Stamen Toner')
region_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d3964156b27e173011b32fe8fbf81cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d3964156b27e173011b32fe8fbf81cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d3964156b27e173011b32fe8fbf81cf = L.map(
#                 &quot;map_9d3964156b27e173011b32fe8fbf81cf&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_521d8d33705e89ab8b1740a3fba7d0ba = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d3964156b27e173011b32fe8fbf81cf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Membuat Data Frame Lonngitude, Latitude dari Top 5 Crime Tertinggi

# %%
country_dict = {
    'country': ['Westminster', 'Southwark', 'Lambeth', 'Camden', 'Newham'],
    'Latitude': [ 51.5002, 51.5014, 51.4995, 51.5517, 51.5255],
    'Longitude': [0.1262, 0.1047, 0.1117, 0.1588, 0.1588 ]
}

df_country_longlat = pd.DataFrame(country_dict)
df_country_longlat
# Out:
#        country  Latitude  Longitude
# 0  Westminster   51.5002     0.1262
# 1    Southwark   51.5014     0.1047
# 2      Lambeth   51.4995     0.1117
# 3       Camden   51.5517     0.1588
# 4       Newham   51.5255     0.1588

# %% [markdown]
# ### Menandai 5 Country pada Foluim Map

# %%
incidents = folium.map.FeatureGroup()
for lat, lng, in zip(df_country_longlat.Latitude, df_country_longlat.Longitude):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
region.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d47f44c34f8ec0e4bcc4e780cb8736b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d47f44c34f8ec0e4bcc4e780cb8736b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d47f44c34f8ec0e4bcc4e780cb8736b3 = L.map(
#                 &quot;map_d47f44c34f8ec0e4bcc4e780cb8736b3&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82a18a9a6c9cc5f4f578424dc29d4c8a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d47f44c34f8ec0e4bcc4e780cb8736b3);
#
#
#             var feature_group_5b11064964e1609ce795441355f948a5 = L.featureGroup(
#                 {}
#             ).addTo(map_d47f44c34f8ec0e4bcc4e780cb8736b3);
#
#
#             var circle_marker_f379de1fdd7625e65645e67694f9a0ff = L.circleMarker(
#                 [51.5002, 0.1262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b11064964e1609ce795441355f948a5);
#
#
#             var circle_marker_9c0123e3d4bcdda081255da04131d381 = L.circleMarker(
#                 [51.5014, 0.1047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b11064964e1609ce795441355f948a5);
#
#
#             var circle_marker_2aeef0e7d02dbb051d4c438066fdcda1 = L.circleMarker(
#                 [51.4995, 0.1117],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b11064964e1609ce795441355f948a5);
#
#
#             var circle_marker_d05cd2116a4c9bbdece72ea3d733a454 = L.circleMarker(
#                 [51.5517, 0.1588],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b11064964e1609ce795441355f948a5);
#
#
#             var circle_marker_5f5cb3831837c390a6badb0d6de4ed23 = L.circleMarker(
#                 [51.5255, 0.1588],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b11064964e1609ce795441355f948a5);
#
#
#             var feature_group_ae32a3048b3d853b973fe1d4af507987 = L.featureGroup(
#                 {}
#             ).addTo(map_d47f44c34f8ec0e4bcc4e780cb8736b3);
#
#
#             var circle_marker_ac07acc2fb85ef68689fee4aec24e959 = L.circleMarker(
#                 [51.5002, 0.1262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &
